# %%
x= [0,0,1,3,3,4,0,0,0,4]
i=0
for i in range(0,len(x)):
    if x[0]!=0:
        break
    x.pop(0)
print(x)
# Out:
# [1, 3, 3, 4, 0, 0, 0, 4]

# %%
x=[3,4,-1,1]
x.sort()
print(x)
while x[0]<=0:
    x.pop(0)
c=1
print(x)
for i in range(0,x[len(x)-1]):
    if x[i]!=c:
        print(c)
        break
    c+=1
# Out:
# [-1, 1, 3, 4]
# [1, 3, 4]
# 2

# %%
class BSTnode:
    def __init__(self, data):
        self.data=data
        self.leftChild=None
        self.rightChild=None

def insertNode(rootnode, nodevalue):
    if rootnode.data==None:
        rootnode.data=nodevalue
    elif nodevalue<=rootnode.data:
        if rootnode.leftChild is None:
            rootnode.leftChild=BSTnode(nodevalue)
        else:
            insertNode(rootnode.leftChild,nodevalue)
    else:
        if rootnode.rightChild is None:
            rootnode.rightChild=BSTnode(nodevalue)
        else:
            insertNode(rootnode.rightChild,nodevalue)

def preOrderTraversal(rootnode):
    if not rootnode:
        return
    print(rootnode.data)
    preOrderTraversal(rootnode.leftChild)
    preOrderTraversal(rootnode.rightChild)

def postOrderTraversal(rootnode):
    if not rootnode:
        return 
    postOrderTraversal(rootnode.leftChild)
    postOrderTraversal(rootnode.rightChild)
    print(rootnode.data)

def inOrderTraversal(rootnode):
    if not rootnode:
        return 
    inOrderTraversal(rootnode.leftChild)
    print(rootnode.data)
    inOrderTraversal(rootnode.rightChild)
def searchnode(rootnode,nodevalue):
    if rootnode.data==nodevalue:
        print("The value is found")
    elif nodevalue<rootnode.data:
        if rootnode.leftChild is None:
            print("The value is not found")
            return 
        searchnode(rootnode.leftChild,nodevalue)
    else:
        if rootnode.rightChild is None:
            print("The value is not found")
            return 
        searchnode(rootnode.rightChild,nodevalue)
    return 
    

    

newBST = BSTnode(None)
insertNode(newBST,70)
insertNode(newBST,50)
insertNode(newBST,90)
insertNode(newBST,30)
insertNode(newBST,60)
insertNode(newBST,80)
insertNode(newBST,100)
insertNode(newBST,20)
insertNode(newBST,40)
insertNode(newBST,10)
# preOrderTraversal(newBST)
# print("--------------------\n")
# inOrderTraversal(newBST)
# print("--------------------\n")
# postOrderTraversal(newBST)
searchnode(newBST,990)
# Out:
# The value is not found

# %%
a=int(input("Enter first number: "))
b=input("Enter second number: ")
try:
    print(a/b)
except:
    print("oh oh not allowed")
# Out:
# Enter first number:  4
# Enter second number:  2
# oh oh not allowed

# %%
import logging 
logging.basicConfig(filename="newfile.txt",level=logging.DEBUG)
try:
    a=int(input("enter first integer no"))
    b=int(input("enter second integer no"))
    print(a/b)
except (ZeroDivisionError,ValueError) as message:
    print(message)
    logging.exception(message)
print("Logging Level is set up.check 'newfile.txt' for log details")
# Out:
# enter first integer no 2
# enter second integer no 0
# division by zero
# Logging Level is set up.check 'newfile.txt' for log details

# %%
import csv
f=open("emp.csv",'a')
a = csv.writer(f)
# a.writerow(["EmpID","Emp Name","Emp Age"])
empid=int(input("enter your empid:  "))
empname=input("enter your empname:  ")                
empage=int(input("enter your empage:  ") ) 
a.writerow([empid,empname,empage])
# Out:
# enter your empid:   105
# enter your empname:   ayush
# enter your empage:   26
# 14

# %%
import csv
f=open("stud.csv",'a')
a = csv.writer(f)
a.writerow(["studID","studName","phy","chem","math","total","percentage","Result"])
stid=int(input("enter your stdid:  "))
stname=input("enter your stdname:  ")                
phy=int(input("enter your phy marks:  ") )
chem=int(input("enter your chem marks:  ") )
math=int(input("enter your math marks:  ") )
total=phy+chem+math
percentage=total/3
result=""
if phy>=40 and chem>=40 and math >=40:
    result="Pass"
else:
    result="Fail"
a.writerow([stid,stname,phy,chem,math,total,percentage,result])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[45], line 5
#       3 a = csv.writer(f)
#       4 a.writerow(["studID","studName","phy","chem","math","total","percentage","Result"])
# ----> 5 stid=int(input("enter your stdid:  "))
#       6 stname=input("enter your stdname:  ")
#       7 phy=int(input("enter your phy marks:  ") )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
