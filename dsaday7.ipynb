# %%
s = "leeltcode"
x= []
for i in range(0,len(s)):
    if s[i] not in x:
        x.append(s[i])
    else:
        x.remove(s[i])
print(x[0])
# Out:
# t

# %%
def factorial(num):
    if num<=1:
        return 1
    return num*factorial(num-1)
print(factorial(4))
# Out:
# 24

# %%
def capifirst(arr):
    result =[]
    if len(arr) == 0:
        return result
    result.append(arr[0][0].upper() + arr[0][1:])
    return result + capifirst(arr[1:])
print(capifirst(['car','taco','banana']))
# Out:
# ['Car', 'Taco', 'Banana']

# %%
def power(base,exponent):
    if exponent == 0:
        return 1
    return base *power(base,exponent-1)
print(power(2,3))
# Out:
# 8

# %%
def productOfArray(arr):
    if len(arr)==0:
        return 1
    return arr[0] * productOfArray(arr[1:])
print(productOfArray([1,2,3]))
# Out:
# 6

# %%
def reverse(string):
    if len(string)<=1:
        return string
    return string[len(string)-1]+reverse(string[0:len(string)-1])
print(reverse("ocat"))
# Out:
# taco

# %%
def recrange(num):
    if num<=0:
        return 0
    return num + recrange(num-1)

print(recrange(6))
# Out:
# 21

# %%
def Pali(strng):
    if len(strng) == 0:
        return True
    if strng[0]!= strng[len(strng)-1]:
        return False
    return Pali(strng[1:-1])
print(Pali("101"))
# Out:
# True

# %%
def someRecursive(arr,cb):
    if

# %%
x = input("enter the number of values and values ")
c = x[0]

# %%
class Tree:
    def __init__(self,data):
        self.data=data
        self.child=[]
    def addChild(self,child):
        self.child.append(child)
        print("child added")
    def __str__(self,level=0):
        ret="      "*level+str(self.data)+"\n"
        for ch in self.child:
            ret+=ch.__str__(level+1)
        return ret
a = Tree("N1")
b = Tree("N2")
c = Tree("N3")
d = Tree("N4")
e = Tree("N5")
f = Tree("N6")
g = Tree("N7")
h = Tree("N8")

a.addChild(b)
a.addChild(c)
b.addChild(d)
b.addChild(e)
c.addChild(f)
d.addChild(g)
d.addChild(h)
print(a)
# Out:
# child added
# child added
# child added
# child added
# child added
# child added
# child added
# N1
#       N2
#             N4
#                   N7
#                   N8
#             N5
#       N3
#             N6

# %%
inp = [1,2,3,4,5]
ip=input("enter the number of steps")

print()
