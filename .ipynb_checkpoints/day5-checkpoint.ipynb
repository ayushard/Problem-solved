# %%
import math
x = int(input("enter number of plots"))
count=0
for i in range(0,x):
    y = int(input("enter the area of plot"))
    root = math.isqrt(y)
    if root*root==y:
        count+=1
print(count)
# Out:
# enter number of plots 12
# enter the area of plot 12
# enter the area of plot 23
# enter the area of plot 24
# enter the area of plot 25
# enter the area of plot 23
# enter the area of plot 16
# enter the area of plot 81
# enter the area of plot 22
# enter the area of plot 1
# enter the area of plot 12
# enter the area of plot 12
# enter the area of plot 12
# 4

# %%
def f(i,values=[]):
    values.append(i)
    print(values)
f(1)
f(2)
f(3)
# Out:
# [1]
# [1, 2]
# [1, 2, 3]

# %%
fruit={}
def addone(index):
    if index in fruit:
        fruit[index]+=1
    else:
        fruit[index]=1
addone("Apple")
addone("apple")
addone("banana")
print(len(fruit))
# Out:
# 3

# %%
### data={}
def adds():
    x=input("enter student name: ")
    y=int(input("enter student mark: "))
    data[x]=y
def track():
    name=input("Enter student name: ")
    if name not in data:
        print("student does not exist")
    else:
        print("student marks are ",data[name])

while True:
    print("Select one of the following")
    print("Select 1 to add a student ")
    print("Select 2 to track ")
    print("Select 3 to exit ")
    m = int(input("enter your choice: "))
    if m == 1:
        adds()
    elif m == 2:
        track()
    elif m==3:
        break;
    else:
        print("please enter a valid choice")
# Out:
# Select one of the following
# Select 1 to add a student
# Select 2 to track
# Select 3 to exit
# enter your choice:  2
# Enter student name:  A
# student does not exist
# Select one of the following
# Select 1 to add a student
# Select 2 to track
# Select 3 to exit
# enter your choice:  3
